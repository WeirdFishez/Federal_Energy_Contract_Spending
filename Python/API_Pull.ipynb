# %%
# Dependencies
# %matplotlib inline

import matplotlib.pyplot as plt
import json
import requests
import os
import pandas as pd
import numpy as np
import requests

from scipy.stats import linregress
from datetime import datetime
import time

# %% [markdown]
# ## US Spending by Award

# %%
for i in range(1,1000):
    
    url = "https://api.usaspending.gov/api/v2/search/spending_by_award"

    payload = json.dumps({
        "page": i,
        "filters": {
            "award_type_codes": ["IDV_A", "IDV_B", "IDV_B_A", "IDV_B_B", "IDV_B_C", "IDV_C","IDV_D","IDV_E"],
            "recipient_scope": "domestic",
            "recipient_type_names": [
                "category_business"
            ],
            "place_of_performance_scope": "domestic",
            "award_amounts": [
                {
                    "lower_bound": 100,
                    "upper_bound": 1600000000000
                }
            ],
            "time_period": [
                {
                    "start_date": "2015-01-01", 
                    "end_date": "2021-01-01"
                }
            ],
        },
        "fields": [
            "Award ID",
            "Start Date",
            "Award Amount",
            "Recipient Name",
            "Description",
            "Contract Award Type",
            "def_codes",
            "Awarding Agency",
            "Awarding Sub Agency"
        ],
        "sort": "Start Date",
        "order": "desc"
    })
    headers = {
        'Content-Type': 'application/json',
        'Cookie': 'cookiesession1=678A3E0DCDEFGHIJKLNOPQRSTUV08936'
    }

    response = requests.request("POST", url, headers=headers, data=payload)

    data = response.json()
    temp_df = pd.DataFrame(data['results'])
    if i == 1:
        temp_df.to_csv('Resources/Data/sample_data.csv', mode='a', index=False, header=True)
    else: temp_df.to_csv('Resources/Data/sample_data.csv', mode='a', index=False, header=False)
    print(f'Page {i} added to csv')
# Out:
# Page 1 added to csv
# Page 2 added to csv
# Page 3 added to csv
# Page 4 added to csv
# Page 5 added to csv
# Page 6 added to csv
# Page 7 added to csv
# Page 8 added to csv
# Page 9 added to csv
# Page 10 added to csv
# Page 11 added to csv
# Page 12 added to csv
# Page 13 added to csv
# Page 14 added to csv
# Page 15 added to csv
# Page 16 added to csv
# Page 17 added to csv
# Page 18 added to csv
# Page 19 added to csv
# Page 20 added to csv
# Page 21 added to csv
# Page 22 added to csv
# Page 23 added to csv
# Page 24 added to csv
# Page 25 added to csv
# Page 26 added to csv
# Page 27 added to csv
# Page 28 added to csv
# Page 29 added to csv
# Page 30 added to csv
# Page 31 added to csv
# Page 32 added to csv
# Page 33 added to csv
# Page 34 added to csv
# Page 35 added to csv
# Page 36 added to csv
# Page 37 added to csv
# Page 38 added to csv
# Page 39 added to csv
# Page 40 added to csv
# Page 41 added to csv
# Page 42 added to csv
# Page 43 added to csv
# Page 44 added to csv
# Page 45 added to csv
# Page 46 added to csv
# Page 47 added to csv
# Page 48 added to csv
# Page 49 added to csv
# Page 50 added to csv
# Page 51 added to csv
# Page 52 added to csv
# Page 53 added to csv
# Page 54 added to csv
# Page 55 added to csv
# Page 56 added to csv
# Page 57 added to csv
# Page 58 added to csv
# Page 59 added to csv
# Page 60 added to csv
# Page 61 added to csv
# Page 62 added to csv
# Page 63 added to csv
# Page 64 added to csv
# Page 65 added to csv
# Page 66 added to csv
# Page 67 added to csv
# Page 68 added to csv
# Page 69 added to csv
# Page 70 added to csv
# Page 71 added to csv
# Page 352 added to csv
# Page 353 added to csv
# Page 354 added to csv
# Page 355 added to csv
# Page 356 added to csv
# Page 357 added to csv
# Page 358 added to csv
# Page 359 added to csv
# Page 360 added to csv
# Page 361 added to csv
# Page 362 added to csv
# Page 363 added to csv
# Page 364 added to csv
# Page 365 added to csv
# Page 366 added to csv
# Page 367 added to csv
# Page 368 added to csv
# Page 369 added to csv
# Page 370 added to csv
# Page 371 added to csv
# Page 372 added to csv
# Page 373 added to csv
# Page 374 added to csv
# Page 375 added to csv
# Page 376 added to csv
# Page 377 added to csv
# Page 378 added to csv
# Page 379 added to csv
# Page 380 added to csv
# Page 381 added to csv
# Page 382 added to csv
# Page 383 added to csv
# Page 384 added to csv
# Page 385 added to csv
# Page 386 added to csv
# Page 387 added to csv
# Page 388 added to csv
# Page 389 added to csv
# Page 390 added to csv
# Page 391 added to csv
# Page 392 added to csv
# Page 393 added to csv
# Page 394 added to csv
# Page 395 added to csv
# Page 396 added to csv
# Page 397 added to csv
# Page 398 added to csv
# Page 399 added to csv
# Page 400 added to csv
# Page 401 added to csv
# Page 402 added to csv
# Page 403 added to csv
# Page 404 added to csv
# Page 405 added to csv
# Page 406 added to csv
# Page 407 added to csv
# Page 408 added to csv
# Page 409 added to csv
# Page 410 added to csv
# Page 411 added to csv
# Page 412 added to csv
# Page 413 added to csv
# Page 414 added to csv
# Page 415 added to csv
# Page 416 added to csv
# Page 417 added to csv
# Page 418 added to csv
# Page 419 added to csv
# Page 420 added to csv
# Page 421 added to csv
# Page 422 added to csv
# Page 423 added to csv
# Page 424 added to csv
# Page 425 added to csv
# Page 426 added to csv
# Page 427 added to csv
# Page 428 added to csv
# Page 429 added to csv
# Page 430 added to csv
# Page 431 added to csv
# Page 432 added to csv
# Page 433 added to csv
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# C:\Users\Chapm\AppData\Local\Temp\ipykernel_17812\3002590904.py in <module>
#      50     if i == 1:
#      51         temp_df.to_csv('Resources/Data/sample_data.csv', mode='a', index=False, header=True)
# ---> 52     else: temp_df.to_csv('Resources/Data/sample_data.csv', mode='a', index=False, header=False)
#      53     print(f'Page {i} added to csv')
#      54
#
# C:\Users\Chapm\.conda\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# C:\Users\Chapm\.conda\envs\PythonData\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# C:\Users\Chapm\.conda\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# C:\Users\Chapm\.conda\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# PermissionError: [Errno 13] Permission denied: 'Resources/Data/sample_data.csv'

# %%
# For potential futuree tuse to break down by industry
naics_dict = {11: "agriculture_forestry_fishing_and_hunting",
21: "mining_quarrying_and_oil_and_gas_extraction",
22: "utilities",
23: "construction",
31: "manufacturing",
32: "manufacturing",
33: "manufacturing",
42: "wholesale_trade",
44: "Retail_trade",
45: "Retail_trade",
48: "Transportation_and_warehousing",
49: "Transportation_and_warehousing",
51: "information",
52: "finance_and_insurance",
53: "real_estate_and_rental_and_leasing",
54: "professional_scientific_and_technical_services",
55: "management_of_companies_and_enterprises",
56: "administrative_and_support_and_waste_management_and_remediation_services",
61: "educational_services",
62: "health_care_and_social_assistance",
71: "arts_entertainment_and_recreation",
72: "accommodation_and_food_services",
81: "other_services",
92: "public_administration"}
